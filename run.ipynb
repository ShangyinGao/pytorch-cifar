# %%
from google.colab import drive
import os
drive.mount('gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at gdrive

# %%
os.chdir('gdrive/My Drive/Colab Notebooks/pytorch-cifar')

# %%
# epoch 400 / [150, 350] / bs 128
# !python main.py
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 1s994ms | Tot: 1m24s | Loss: 1.918 | Acc: 31.542% (15771/50000) | lr: 0.1000 391/391
#  [================================================================>]  Step: 57ms | Tot: 5s878ms | Loss: 1.586 | Acc: 41.680% (4168/10000) 100/100
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 154ms | Tot: 1m22s | Loss: 1.422 | Acc: 48.056% (24028/50000) | lr: 0.1000 391/391
#  [================================================================>]  Step: 57ms | Tot: 5s849ms | Loss: 1.531 | Acc: 48.000% (4800/10000) 100/100
# Saving..
#
# Epoch: 2
#  [================================================================>]  Step: 160ms | Tot: 1m23s | Loss: 1.123 | Acc: 59.782% (29891/50000) | lr: 0.1000 391/391
# ...
